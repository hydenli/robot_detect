# %% [markdown]
# # Facebook Recruiting IV: Human or Robot?

# %% [markdown]
# Name : Leo

# %% [markdown]
# # 定义

# %% [markdown]
# ## 项目概览

# %% [markdown]
# 随着互联网的发展，出现了提供各种服务的互联网产品，互联网竞拍平台便是其中之一，互联网竞价平台提供了一个虚拟的线上竞拍空间，使得商品持有人可以把所持商品放置到竞拍空间，让对其感兴趣的用户进行竞价购买。在竞拍过程中，用户可以进行多次竞价，使得商品竞拍价格可达到持有人预期或之上的价格。但随着机器人用户的进入，使得竞拍过程不再对真实用户不再公平，机器人可推高价格，迫使真实用户出更高的价格或放弃出价，从而打破竞拍的价格平衡，用户及平台都是极大的伤害。所以我们需要基于对平台所有用户基本数据及行为数据，找出潜在的机器人用户并剔除平台，使得竞拍过程回归公平。

# %% [markdown]
# 此项目来自于kaggle[5]，kaggle平台提供了两项数据，一是包括用户的id、地址、支付方式的用户数据，二是平台每一次的竞价行为数据，我们将对这些数据进行处理、分析、训练、预测，发现潜在的机器人用户。

# %% [markdown]
# ## 问题说明

# %% [markdown]
# 项目目标是发现用户集合中的机器人用户，通过训练给定的用户数据，识别用户是否是机器人，这是一个监督学习的二分类问题。

# %% [markdown]
# 这个项目中，我将
# - 对数据进行探索及可视化分析，找到特征工程的方向。
# - 对数据进行缺省值处理，字符串数字化。
# - 由于用户数据特征数量过少，重点还将基于对竞价行为数据的处理，为用户数据增加特征。
# - 而后对各个分类器进行训练，训练完成之后进行对比，找到最有效的分类器。
# - 然后对分类器进行调参，找到最优参数组合。
# - 通过auc面积对模型进行评估。

# %% [markdown]
# ## 指标

# %% [markdown]
# 对于二分类问题，，我们将使用下列指标：
# 1. AUC：（ROC曲线下方的面积大小）来做模型的评估指标：理想指标值为1
#     统计一下所有的 M×N(M为正类样本的数目，N为负类样本的数目)个正负样本对中，有多少个组中的正样本的score大于负样本的score。当二元组中正负样本的 score相等的时候，按照0.5计算。然后除以MN。实现这个方法的复杂度为O(n^2)。n为样本数（即n=M+N）。
# ![](imgs/auc.png)
#
# 2. TIME：即分类器训练数据所花费的时间，用于评估分类器的性能

# %% [markdown]
# #  分析

# %% [markdown]
# ## 数据探索

# %% [markdown]
# 该项目提供三份数据，训练用户数据以及测试用户数据、竞拍行为数据：
#     * 训练用户数据（train.csv）－为用户基础信息数据，用户ID（bidder_id）、支付账户（payment_account）、住址（address），其中还每个用户都已提前被标记了是否为机器人（outcome），可基于此数据对模型进行训练。
#     * 训练测试数据（test.csv）－为用户基础信息数据，尚未做机器人标记，接下来我们将对这部分用户进行判定其为机器人用户的概率。
#     * 竞拍行为数据（bids.csv）-平台某段时期内的所有竞拍的行为数据，纪录了每一次竞价行为的行为ID（bid_id），用户ID(bidder_id)，竞拍ID（aution），物品类型（merchandise），设备类型（device），竞拍时间（time），国家（country），IP，外链（URL），时间等等数据。我们将通过分析真实用户及机器人用户行为之间的共性与区别，找出真正的机器人用户。

# %% [markdown]
# 首先我们先对训练用户数据进行分析，先导入数据

# %%
from sklearn.ensemble import VotingClassifier
import numpy as np
import pandas as pd
from time import time
from sklearn.cross_validation import train_test_split
from sklearn.model_selection import ShuffleSplit


from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
# import lightgbm as lgb
from sklearn.metrics import roc_auc_score, make_scorer
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import learning_curve

# import lightgbm as lgb
import xgboost as xgb

bids = pd.read_csv("bids.csv")
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %matplotlib inline

labelEncoder=None

print bids.shape
print train.shape
print test.shape
# Out:
# /usr/local/lib/python2.7/dist-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# (7656334, 9)
# (2013, 4)
# (4700, 3)

# %%
def load_data(bids_data,train_data,test_data):
    train_data.index=train_data.bidder_id
    test_data.index=test_data.bidder_id
    train_data=train_data.append(test_data)
    #all_data=pd.merge(bids_data, train_data, how='inner'可见, on='bidder_id', right_index=True)
    #all_data= bids_data.join(train_data, on='bidder_id')
    outcome = train_data.outcome  
    train_data = train_data.drop('outcome',axis=1)  
    train_data.insert(3,'outcome',outcome)  
    all_data=bids_data.merge(train_data, on='bidder_id', how='left')
    return train_data,all_data

# %% [markdown]
# 通过对数据字段含义研究发现，bidder_id为用户的唯一标示，不可重复，且没有具体规律可循，初步可以判断此特征对于分类器训练没有帮助，可考虑删除此特征。

# %%
print "| train 特征名称 | 特征类型 |"
print "| :----: | :----: |"

for col, col_data in train.iteritems():
    print "|",col,'|',col_data.dtype,"|"
# Out:
# | train 特征名称 | 特征类型 |
# | :----: | :----: |
# | bidder_id | object |
# | payment_account | object |
# | address | object |
# | outcome | float64 |

# %%
print "特征数量: ",train.shape[1]
# Out:
# 特征数量:  4

# %% [markdown]
# 由上表可见：
#     * 用户ID、付款方式、地址内容都为字符串，若要进行训练，我们需要把字符串转化为数字，以使分类器能够发挥作用。
#     * 其次，训练数据的特征数量过少，不足以让我们准确识别机器人用户，我们需要通过对竞拍行为数据对每个用户的竞拍行为进行特征统计，并把其当作训练特征加入训练用户数据，用以提高预测的准确性。

# %% [markdown]
# 再对竞拍行为数据进行分析

# %%
print "| bids 特征名称 | 特征类型 |"
print "| :----: | :----: |"

for col, col_data in bids.iteritems():
    print "|",col,'|',col_data.dtype,"|"
# Out:
# | bids 特征名称 | 特征类型 |
# | :----: | :----: |
# | bid_id | int64 |
# | bidder_id | object |
# | auction | object |
# | merchandise | object |
# | device | object |
# | time | int64 |
# | country | object |
# | ip | object |
# | url | object |

# %% [markdown]
# 可知数据中由大量的字符串，需要都将之转变为数字再进行模型训练。

# %% [markdown]
# 下面我门将每条用户竞拍行为数据关联上该用户的账户信息。

# %%
def dropNullColumn(data,column_name):    
    strange_data=data[pd.isnull(data[column_name])]
    data=data.drop(strange_data.index)
    return data

# %%
explo_data=bids.merge(train.append(test), on='bidder_id', how='left')


# explo_data=dropNullColumn(explo_data,'outcome')
# print explo_data
# explo_data=explo_data.drop(a)

# %% [markdown]
# 我们将检查每个特征值的空值数量

# %%
def checkNullValue(data):
    for col, col_data in data.iteritems():
        print col,':',data[pd.isnull(data[col])].shape[0]

checkNullValue(bids)
# Out:
# bid_id : 0
# bidder_id : 0
# auction : 0
# merchandise : 0
# device : 0
# time : 0
# country : 8859
# ip : 0
# url : 0

# %% [markdown]
# 查出竞拍行为数据中，有8859条数据是没有国家数据的，我门对这些国家为空值的数据设置默认值'none'，用以当作一个独立的值进行训练。

# %%
bids['country']= bids['country'].fillna('none')
checkNullValue(bids)
# Out:
# bid_id : 0
# bidder_id : 0
# auction : 0
# merchandise : 0
# device : 0
# time : 0
# country : 0
# ip : 0
# url : 0

# %% [markdown]
# ##  探索性可视化

# %% [markdown]
# #### 用户竞拍频度

# %% [markdown]
# 接下来我们将通过可视化图形对用户行为统计特征进行进一步分析。

# %% [markdown]
# 我们在某一auction下按照竞拍时间来画出真假用户的竞拍次数分布，图中红色分布为机器人用户，蓝色分布为真实用户

# %%
bots=explo_data[(explo_data['outcome']==1)&(explo_data['auction']=='wa00e')]['time']
mans=explo_data[(explo_data['outcome']==0)&(explo_data['auction']=='wa00e')]['time']

fig=sns.distplot(bots,bins=200,color='r')
fig=sns.distplot(mans,bins=200,color='b')
fig.set(xlabel='time',ylabel='bids_number',title='Figure-1')

# %% [markdown]
# 如图1所示，机器人用户会在集中在短时间内进行大量的竞价行为，而真实用户的行为则相对平均分布在时间线上，则我们可以把在auction下的用户平均竞价次数，最大竞价次数，平均竞价时间间隔作为统计特征进行训练。

# %% [markdown]
# #### 国家登录数量

# %% [markdown]
# 接下来，我们对用户登录的国家数量分布进行分析，图2统计了每个用户在平台上登录进行竞拍的国家数量汇总。横坐标为某用户登录过的国家数量，纵坐标为次登录过对应国家数量的用户占比。红色为机器人用户，蓝色为真实用户。

# %%
bots=explo_data[explo_data['outcome']==1].groupby([explo_data['bidder_id'],explo_data['country']]).size().count(level='bidder_id')
mans=explo_data[explo_data['outcome']==0].groupby([explo_data['bidder_id'],explo_data['country']]).size().count(level='bidder_id')
fig=sns.distplot(bots,bins=200,color='r')
fig=sns.distplot(mans,bins=200,color='b')
fig.set(xlabel='country',ylabel='bids_number',title='Figure-2')

# %% [markdown]
# 由图2可知，大量真实用户所登录过的国家不超过20个，而机器人用户登录过的国家数量分布很平缓，不够集中，大概在0～100之间，其中还有部分机器人用户登录国家超过170多个。所以我们可以根据用户登录过的国家数量统计进行特征训练。

# %% [markdown]
# #### 设备登录数量

# %% [markdown]
# 接下来，我们对用户登录过的设备数量分布进行分析，图3统计了每个用户在平台上登录进行竞拍的设备数量汇总。横坐标为某用户登录过的设备类型数量，纵坐标为次登录过对应设备数量的用户占比。红色为机器人用户，蓝色为真实用户。

# %%
bots=explo_data[explo_data['outcome']==1].groupby([explo_data['bidder_id'],explo_data['device']]).size().count(level='bidder_id')
mans=explo_data[explo_data['outcome']==0].groupby([explo_data['bidder_id'],explo_data['device']]).size().count(level='bidder_id')
fig=sns.distplot(bots,bins=200,color='r')
fig=sns.distplot(mans,bins=200,color='b')
fig.set(xlabel='device',ylabel='bids_number',title='Figure-3')

# %% [markdown]
# 由图3可知，大量真实用户所登录过的设备不超过100个，而机器人用户登录过的设备数量分布很平缓，不够集中，大概在0～700之间，其中还有部分机器人用户登录设备数量超过1000多个。所以我们可以根据用户登录过的设备数量统计进行特征训练。

# %% [markdown]
# #### IP登录数量

# %% [markdown]
# 下面，我们对平均一次竞拍活动中用户的url登录次数分布进行分析。横坐标为某用户平均一次竞拍活动中登录过的url数量，纵坐标为次登录过对应url数量的用户占比。红色为机器人用户，蓝色为真实用户。

# %%
def url_num_mean1(data):
    return data.groupby([data['auction'],data['url']]).size().count(0).mean()
bots=explo_data[(explo_data['outcome']==1)].groupby([explo_data['bidder_id']]).apply(url_num_mean1)
mans=explo_data[(explo_data['outcome']==0)].groupby([explo_data['bidder_id']]).apply(url_num_mean1)

fig=sns.distplot(bots,bins=200,color='r')
fig=sns.distplot(mans,bins=200,color='b')
fig.set(xlabel='url',ylabel='bids_number',title='Figure-4')

# %% [markdown]
# 由上图可知，大量真实用户所登录的url相对集中，在10个url之内，而机器人用户登录过的url数量分布相对平缓，大概在0～20之间，其中还有部分机器人用户登录url数量超过100多个。所以我们可以根据用户登录过的url数量统计进行特征训练。

# %% [markdown]
# ## 算法与方法

# %% [markdown]
# 由前面分析可知，特征大部分为字符串，我们需将其转化成数值化，且某些特征字符串类型过多，如果使OneHotEncoding会造成特征维度灾难，对每个特征进行LabelEncoding[1]处理。
#
# 同时由于这些数据内部缺少相关性，对于这类二分类监督学习问题，所以我们用基于决策树当分类器来训练。决策树的优点是：可处理不相关的特征，忽略数据之间的关联性；不需要对数据归一化，数据准备相对简单；易于解释及说明；对应的缺点是：不支持在线学习，所以当有新样本时，必须要重建决策树。但在此项目中我们不会涉及到在线学习，所以可忽略。单一的决策数容易造成过拟合，所以我们将通过集成算法Boosting和Bagging来降低过拟合。在Boosting算法中，我们将采用基于Gradient Boosting的Xgboost[2]，其由于优秀的性能以及更高的准确率在已在kaggle平台获得了大量用户支持。第二是微软新出的lightgbm，同样是基于gradient boosting的boosting框架，由于其使用了Histogram算法，相比xgboost的pre-sorted算法有着更快的处理速度和更低的内存消耗[8]。以及基于Bagging算法的randomforest，其优势是如果有很大一部分的特征遗失，仍可以维持准确度，它能够处理很高维度（feature很多）的数据，并且不用做特征选择。
#
#
# 我们将在在3个模型中筛选出最优分类器作为最终预测分类器使用。评价分类器的指标即为上文所提AUC及Time。

# %% [markdown]
# ### Xgboost

# %% [markdown]
# #### Xgboost简介:

# %% [markdown]
# 基于Gradient Boosting的优化实现，建立多个基于cart决策树弱分类器,每一次建立模型是基于之前模型的梯度下降方向。让损失函数在梯度下降方向不断的减小，达到最优值。
#
# xgboost相较于传统Gradient Boosting优势在于：加入了正则项，用于控制模型的复杂度，防止过拟合；传统GBDT在优化时只用到一阶导数信息，xgboost则对代价函数进行了二阶泰勒展开，同时用到了一阶和二阶导数，对损失函数做出来改进。分布式加权直方图算法[7]，提高算法训练效率；对于特征的值有缺失的样本，xgboost可以自动学习出它的分裂方向。
#
# 但由于其基于pre-sorted算法，导致每一次的迭代计算是都要遍历整个训练数据，造成了空间、时间的大量消耗。

# %% [markdown]
# #### xgboost参数介绍：

# %% [markdown]
# Parameter for Tree Booster
#
# * eta [default=0.3]
#     - 为了防止过拟合，更新过程中用到的收缩步长。在每次提升计算之后，算法会直接获得新特征的权重。 eta通过缩减特征的权重使提升计算过程更加保守。缺省值为0.3
#     - 取值范围为：[0,1]
#     - 通常最后设置eta为0.01~0.2
# * gamma [default=0]
#     - minimum loss reduction required to make a further partition on a leaf node of the tree. the larger, the more conservative the algorithm will be.
#     - range: [0,∞]
#     - 模型在默认情况下，对于一个节点的划分只有在其loss function 得到结果大于0的情况下才进行，而gamma 给定了所需的最低loss function的值
#     - gamma值使得算法更conservation，且其值依赖于loss function ，在模型中应该进行调参。
# * max_depth [default=6]
#     - 树的最大深度。缺省值为6
#     - 取值范围为：[1,∞]
#     - 指树的最大深度
#     - 树的深度越大，则对数据的拟合程度越高（过拟合程度也越高）。即该参数也是控制过拟合
#     - 建议通过交叉验证（xgb.cv ) 进行调参
#     - 通常取值：3-10
# * min_child_weight [default=1]
#     - 孩子节点中最小的样本权重和。如果一个叶子节点的样本权重和小于min_child_weight则拆分过程结束。在现行回归模型中，这个参数是指建立每个模型所需要的最小样本数。该成熟越大算法越conservative。即调大这个参数能够控制过拟合。
#     - 取值范围为: [0,∞]
# * max_delta_step [default=0]
#     - Maximum delta step we allow each tree’s weight estimation to be. If the value is set to 0, it means there is no constraint. If it is set to a positive value, it can help making the update step more conservative. Usually this parameter is not needed, but it might help in logistic regression when class is extremely imbalanced. Set it to value of 1-10 might help control the update
#     - 取值范围为：[0,∞]
#     - 如果取值为0，那么意味着无限制。如果取为正数，则其使得xgboost更新过程更加保守。
#     - 通常不需要设置这个值，但在使用logistics 回归时，若类别极度不平衡，则调整该参数可能有效果
# * subsample [default=1]
#     - 用于训练模型的子样本占整个样本集合的比例。如果设置为0.5则意味着XGBoost将随机的从整个样本集合中抽取出50%的子样本建立树模型，这能够防止过拟合。
#     - 取值范围为：(0,1]
# * colsample_bytree [default=1]
#     - 在建立树时对特征随机采样的比例。缺省值为1
#     - 取值范围：(0,1]
# * colsample_bylevel[default=1]
#     - 决定每次节点划分时子样例的比例
#     - 通常不使用，因为subsample和colsample_bytree已经可以起到相同的作用了
# * scale_pos_weight[default=0]
#     - A value greater than 0 can be used in case of high class imbalance as it helps in faster convergence.
#     - 大于0的取值可以处理类别不平衡的情况。帮助模型更快收敛
#
#
# Task Parameters
#
# * objective [ default=reg:linear ]
#     - 定义学习任务及相应的学习目标
# * base_score [ default=0.5 ]
#     - the initial prediction score of all instances, global bias
# * eval_metric [ default according to objective ]
#     - 校验数据所需要的评价指标，不同的目标函数将会有缺省的评价指标（rmse for regression, and error for classification, mean average precision for ranking）
# * seed [ default=0 ]
#     - 随机数的种子。缺省值为0
#     - 可以用于产生可重复的结果（每次取一样的seed即可得到相同的随机划分）

# %% [markdown]
# ### LightGBM

# %% [markdown]
# #### LightGBM简介：

# %% [markdown]
# LightGBM 是一个梯度 boosting 框架，基于Histogram的决策树算法。
#
# 直方图算法的基本思想是先把连续的浮点特征值离散化成k个整数，同时构造一个宽度为k的直方图。在遍历数据的时候，根据离散化后的值作为索引在直方图中累积统计量，当遍历一次数据后，直方图累积了需要的统计量，然后根据直方图的离散值，遍历寻找最优的分割点。如下图
# ![](imgs/histgram.png)
# 其次是深度限制的Leaf-wise的叶子生长策略，与传统的Level-wise相比，Level-wise是对同一层的叶子做无差别的分裂，造成无必要的浪费。如下图所示
# ![](imgs/level-wise.png)
#
# Leaf-wise是找到信息增益最大的叶子进行分裂，但又通过限制其分裂的深度降低过拟合这样可降低误差，提高精度。如下图所示
# ![](imgs/leaf-wise.png)
#
# 其有以下优势：
# - 更快的训练效率
# - 低内存使用
# - 更好的准确率
# - 支持并行学习
# - 可处理大规模数据

# %% [markdown]
# #### LightGBM参数：
#
# * num_leaves:
#     - 一颗树的叶子数量
# * num_iterations
#     - boosting迭代次数
# * learning_rate
#     - 学习速率
# * num_leaves
#     - 一个决策树的叶子数量
# * num_threads
#     - 线程数量
# * max_depth
#     - 决策树的最大深度
#     - 取值范围为：[1,∞]
# * min_data_in_leaf
#     - 一个叶子的最小数据数量，可以用于过拟合
# * min_sum_hessian_in_leaf
#     - 一片叶子的hessian之和，同样用于过拟合
# * feature_fraction
#     - 模型每次迭代将选取部分特征进行训练，可用于提高训练速度以及预防过拟合
# * feature_fraction_seed
#     - 随机种子的特征占比
# * bagging_fraction
#     - 类似feature_fraction，但其是每次迭代随机选择部分数据，可用于提高训练速度以及预防过拟合
# * bagging_freq
#     - bagging的频度
# * bagging_seed
#     - bagging_seed的随机种子
# * early_stopping_round
#     - 在第early_stopping_round轮中，一个测试数据的验证指标没有提升了，则停止训练。
# * lambda_l1
#     - L1正则项
# * lambda_l2
#     - L2正则项
# * min_gain_to_split
#     - 执行分裂的最小增益

# %% [markdown]
# ### RandomForest

# %% [markdown]
# #### RandomForest简介：
# 随机抽取其中的m(m << M)个特征进行训练，并对结果进行输出，且其最终输出结果是由多棵树输出结果的投票决定。因为样本的抽取，特征的抽取已经保证了随机性，大大减少了overfitting的可能性。

# %% [markdown]
# #### RandomForest参数：

# %% [markdown]
# * n_estimators=10：
#     - 决策树的个数，越多越好，但是性能就会越差，至少100左右（具体数字忘记从哪里来的了）可以达到可接受的性能和误差率。
# * bootstrap=True：
#     - 是否有放回的采样。
# * oob_score=False：
#     - oob（out of band，带外）数据，即：在某次决策树训练中没有被bootstrap选中的数据。多单个模型的参数训练，我们知道可以用cross validation（cv）来进行，但是特别消耗时间，而且对于随机森林这种情况也没有大的必要，所以就用这个数据对决策树模型进行验证，算是一个简单的交叉验证。性能消耗小，但是效果不错。
# * n_jobs=1：
#     - 并行job个数。这个在ensemble算法中非常重要，尤其是bagging（而非boosting，因为boosting的每次迭代之间有影响，所以很难进行并行化），因为可以并行从而提高性能。1=不并行；n：n个并行；-1：CPU有多少core，就启动多少job
# * warm_start=False：
#     - 热启动，决定是否使用上次调用该类的结果然后增加新的。
# * class_weight=None：
#     - 各个label的权重。

# %% [markdown]
# ## 基准测试

# %% [markdown]
# 该项目为Kaggle竞赛项目之一，Private Leaderboard排名第一的auc分数为0.94。如果我们不做特征工程，不调参的情况下xgboost,lightgbm,random forest的平均预测分数在kaggle的提交分数达到了0.5。由于硬件限制，无法对大量数据进行复杂处理，我们把目标auc定为0.9以上。

# %% [markdown]
# # 方法

# %% [markdown]
# ## 数据预处理

# %% [markdown]
# 加载数据

# %%
merge_data,all_data=load_data(bids,train,test)

# %% [markdown]
# 异常值、缺失值处理
# 我们获取训练用户及测试用户的总用户数量、以及从竞拍行为数据中计算出参加竞拍的用户数。

# %%
print '测试用户＋训练用户：',merge_data.shape[0]
print '参加竞拍活动的用户：',all_data.drop_duplicates('bidder_id').shape[0]
# Out:
# 测试用户＋训练用户： 6713
# 参加竞拍活动的用户： 6614

# %% [markdown]
# 也就是说训练和测试用户中将有部分用户没有竞拍行为数据可用来做为特征，无法用于训练。对于这部分用户的特征我们将用缺省值0填充。

# %% [markdown]
# 通过对竞拍行为数据的特征统计，整理出新的特征并加入用户数据中用于训练模型，这些特征都是经过观察有对测试auc值提高的作用的。整理出的新特征有：
# * 竞拍次数
#     - 每个用户一次拍卖活动中的最大竞拍次数
#     - 每个用户一次拍卖活动中的最小竞拍次数
#     - 每个用户一次拍卖活动中的平均竞拍次数
#     - 每个用户参与的拍卖活动次数
#     - 每次竞拍活动中的竞拍时间间隔方差平均值
#     - 每次竞拍活动中的竞拍时间间隔方差最小值
#     - 所有竞拍行为的平均竞价时间间隔
#     - 所有竞拍行为的最小竞价时间间隔
#     - 所有竞拍行为的最大竞价时间间隔
# * 商品类型
#     - 每个用户在平台上竞拍商品类型的平均数量
#     - 每个用户在平台上竞拍商品类型的最大数量
# * 设备数量
#     － 每个用户一次竞拍活动中登录过的平均设备数量
#     － 每个用户一次竞拍活动中登录过的最大设备数量
#     － 每个用户在平台上所登录过的设备数量
# * 国家数量
#     - 每个用户在平台竞拍登录过的国家数量
#     - 每次竞拍活动用户平均登录的国家数量
#     - 每次竞拍活动用户最多登录的国家数量
# * IP数量
#     - 每个用户一次竞拍活动中登录过平均IP数量
#     - 每个用户一次竞拍活动中登录过最大IP数量
#     - 每个用户所有竞拍活动中登录过总IP数量
# * url数量
#     - 每个用户一次竞拍活动中url的登录次数
#     - 每个用户平均通过一个url的进行的竞拍次数
#     - 每个用户在一次竞拍活动中登录的最大url数量
#     - 每个用户在一次竞拍活动中登录的最小url数量
#
#
#
#
# 通过调试发现，去掉以下特征，可提高auc：
# * address
# * bidder_id

# %%
all_data[all_data['bidder_id']=='003180b29c6a5f8f1d84a6b7b6f7be57tjj1o']
# Out:
#           bid_id                              bidder_id auction merchandise  \
# 3967330  3967330  003180b29c6a5f8f1d84a6b7b6f7be57tjj1o   obbny      mobile
# 6166636  6166636  003180b29c6a5f8f1d84a6b7b6f7be57tjj1o   cqsh6      mobile
# 7140567  7140567  003180b29c6a5f8f1d84a6b7b6f7be57tjj1o   efh5o      mobile
#
#            device              time country              ip              url  \
# 3967330  phone420  9640018631578947      id    44.241.8.179  sj4jidex850loas
# 6166636  phone102  9700605052631578      id    190.88.89.83  sj4jidex850loas
# 7140567  phone257  9705974315789473      id  115.47.140.180  vasstdc27m7nks3
#
#                                        address  \
# 3967330  a3d2de7675556553a5f08e4c88d2c228iami0
# 6166636  a3d2de7675556553a5f08e4c88d2c228iami0
# 7140567  a3d2de7675556553a5f08e4c88d2c228iami0
#
#                                payment_account  outcome
# 3967330  a3d2de7675556553a5f08e4c88d2c22841s2u      NaN
# ...

# %%
# t= all_data.groupby([all_data['bidder_id'],all_data['auction']])['time'].std().fillna(0)
# print t

# %%
def handle_acution_num(train_data,all_data):
    #每个用户一次拍卖活动中的最大竞拍次数
    train_data['max_auction_num']= all_data.groupby([all_data['bidder_id'],all_data['auction']]).size().max(level=0)
    train_data['max_auction_num']= train_data['max_auction_num'].fillna(0)
    
    #每个用户一次拍卖活动中的最小竞拍次数
    train_data['min_auction_num']=all_data.groupby([all_data['bidder_id'],all_data['auction']]).size().min(level=0)
    train_data['min_auction_num']= train_data['min_auction_num'].fillna(0)
    
    #每个用户一次拍卖活动中的平均竞拍次数
    train_data['per_auction_num']= all_data.groupby([all_data['bidder_id'],all_data['auction']]).size().mean(level=0)
    train_data['per_auction_num']= train_data['per_auction_num'].fillna(0)
    
    #每个用户参与的拍卖活动次数
    train_data['count_auction_num']=all_data.groupby([all_data['bidder_id'],all_data['auction']]).size().count(level=0)
    train_data['count_auction_num']= train_data['count_auction_num'].fillna(0)
    
    #每次竞拍活动中的竞拍时间间隔方差平均值
    train_data['count_auction_std']= all_data.groupby([all_data['bidder_id'],all_data['auction']])['time'].std().fillna(0).mean(level='bidder_id')
    train_data['count_auction_std']= train_data['count_auction_std'].fillna(0)
    
    #每次竞拍活动中的竞拍时间间隔方差最小值
    train_data['count_auction_max']= all_data.groupby([all_data['bidder_id'],all_data['auction']])['time'].std().fillna(0).max(level='bidder_id')
    train_data['count_auction_max']= train_data['count_auction_max'].fillna(0)
     
    #所有竞拍行为的平均竞价时间间隔
    train_data['count_auction_time_mean']=all_data.groupby([all_data['bidder_id']]).apply(time_mean)
    train_data['count_auction_time_mean']= train_data['count_auction_time_mean'].fillna(0)
    #所有竞拍行为的最小竞价时间间隔
    train_data['count_auction_time_min']=all_data.groupby([all_data['bidder_id']]).apply(time_min)
    train_data['count_auction_time_min']= train_data['count_auction_time_min'].fillna(0)

#     train_data['auction_time_min']=all_data.groupby([all_data['bidder_id']]).apply(min_time)
#     train_data['auction_time_min']=train_data['auction_time_min'].fillna(-1)

    #所有竞拍行为的最大竞价时间间隔
    train_data['count_auction_time_max']=all_data.groupby([all_data['bidder_id']]).apply(time_std)
    train_data['count_auction_time_max']= train_data['count_auction_time_max'].fillna(0)
    
#     print train_data
    return train_data

def time_mean(data):
    result=data.groupby([data['auction']])['time'].aggregate(lambda x: (np.max(x)-np.min(x))/x.shape[0]).mean()
    return result

def time_std(data):
    result=data.groupby([data['auction']])['time'].aggregate(lambda x: (np.max(x)-np.min(x))/x.shape[0]).max()
    return result

def time_min(data):
    result=data.groupby([data['auction']])['time'].aggregate(lambda x: (np.max(x)-np.min(x))/x.shape[0]).min()
    return result

# %%
def handle_merchandise_num(train_data,all_data):
    a=all_data.groupby([all_data['bidder_id'],all_data['merchandise']])
    asize=a.size()
    #每个用户在平台上竞拍商品类型的最大数量
    train_data['max_merchandise_num']=asize.max(level=0)
    train_data['max_merchandise_num']= train_data['max_merchandise_num'].fillna(0)
    #每个用户在平台上竞拍商品类型的平均数量
    train_data['mean_merchandise_num']=asize.mean(level=0)
    train_data['mean_merchandise_num']= train_data['mean_merchandise_num'].fillna(0)
        
    return train_data

# %%
def handle_device_num(train_data,all_data):
    #每个用户一次竞拍活动中登录过的平均设备数量
    train_data['mean_device_num']=all_data.groupby([all_data['bidder_id']]).apply(device_mean)
    train_data['mean_device_num']= train_data['mean_device_num'].fillna(0)
    #每个用户一次竞拍活动中登录过的最大设备数量
    train_data['max_device_num']= all_data.groupby([all_data['bidder_id']]).apply(device_max)
    train_data['max_device_num']= train_data['max_device_num'].fillna(0)
    
    #每个用户在平台上所登录过的设备数量
    a=all_data.groupby([all_data['bidder_id'],all_data['device']])
    asize=a.size()
    train_data['count_device']= asize.count(level=0)
    train_data['count_device']= train_data['count_device'].fillna(0)
    return train_data

def device_mean(data):
    f=data.groupby([data['auction'],data['device']]).size()
    z= f.count(0)
    z=z.mean()
#     z['bidder_id']=data['bidder_id']
#     print z
    return z

def device_max(data):
    f=data.groupby([data['auction'],data['device']]).size()
    z= f.count(0)
    z=z.max()
#     z['bidder_id']=data['bidder_id']
#     print z
    return z

# %%
def handle_country_num(train_data,all_data):
    #每个用户在平台竞拍登录过的国家数量
    a=all_data.groupby([all_data['bidder_id'],all_data['country']])
    asize=a.size()
    train_data['count_country']= asize.count(level=0)
    train_data['count_country']= train_data['count_country'].fillna(0)
    
    #每次竞拍活动用户平均登录的国家数量
    train_data['count_auction_mean_country']=all_data.groupby([all_data['bidder_id']]).apply(country_mean)
    train_data['count_auction_mean_country']= train_data['count_auction_mean_country'].fillna(0)
    
    #每次竞拍活动用户最多登录的国家数量
    train_data['count_auction_max_country']=all_data.groupby([all_data['bidder_id']]).apply(country_max)
    train_data['count_auction_max_country']= train_data['count_auction_max_country'].fillna(0)      
    return train_data


def country_max(data):
    f=data.groupby([data['auction'],data['country']]).size()
    z= f.count(0)
    z=z.max()
#     z['bidder_id']=data['bidder_id']
#     print z
    return z

def country_mean(data):
    f=data.groupby([data['auction'],data['country']]).size()
    z= f.count(0)
    z=z.mean()
#     z['bidder_id']=data['bidder_id']
#     print z
    return z

# %%
def handle_ip_num(train_data,all_data):
    #每个用户一次竞拍活动中登录过平均IP数量
    train_data['mean_auction_ip']=all_data.groupby([all_data['bidder_id']]).apply(ip_mean)
    train_data['mean_auction_ip']= train_data['mean_auction_ip'].fillna(0)

     #每个用户一次竞拍活动中登录过最大IP数量
    train_data['max_auction_ip']=all_data.groupby([all_data['bidder_id']]).apply(ip_max)
    train_data['max_auction_ip']= train_data['max_auction_ip'].fillna(0)
    
     #每个用户所有竞拍活动中登录过总IP数量
    train_data['count_ip']= all_data.groupby([all_data['bidder_id'],all_data['ip']]).size().count(level=0)
    train_data['count_ip']= train_data['count_ip'].fillna(0)
    
    return train_data

def ip_mean(data):
    f=data.groupby([data['auction'],data['ip']]).size()
    z= f.count(0)
    z=z.mean()
#     z['bidder_id']=data['bidder_id']
#     print z
    return z

def ip_max(data):
    f=data.groupby([data['auction'],data['ip']]).size()
    z= f.count(0)
    z=z.max()
#     z['bidder_id']=data['bidder_id']
#     print z
    return z

# %%
def handle_url_num(train_data,all_data):
    #每个用户一次竞拍活动中url的登录次数
    train_data['mean_auction_url_num']=all_data.groupby([all_data['bidder_id']]).apply(url_num_mean)
    train_data['mean_auction_url_num']= train_data['mean_auction_url_num'].fillna(0)
    
    #每个用户平均通过一个url的进行的竞拍次数
    train_data['mean_url_num']=all_data.groupby([all_data['bidder_id'],all_data['url']]).size().mean(level=0)
    train_data['mean_url_num']=train_data['mean_url_num'].fillna(0)
    
    #每个用户在一次竞拍活动中登录的最大url数量
    train_data['max_url_num']= all_data.groupby([all_data['bidder_id']]).apply(url_num_max)
    train_data['max_url_num']= train_data['max_url_num'].fillna(0)
    #每个用户在一次竞拍活动中登录的最小url数量
    train_data['min_url_num']= all_data.groupby([all_data['bidder_id']]).apply(url_num_min)
    train_data['min_url_num']= train_data['min_url_num'].fillna(0)

    return train_data

def url_num_mean(data):
    f=data.groupby([data['auction'],data['url']]).size()
    z= f.count(0)
    z=z.mean()
#     z['bidder_id']=data['bidder_id']
#     print z
    return z

def url_num_max(data):
    f=data.groupby([data['auction'],data['url']]).size()
    z= f.count(0)
    z=z.max()
#     z['bidder_id']=data['bidder_id']
#     print z
    return z

def url_num_min(data):
    f=data.groupby([data['auction'],data['url']]).size()
    z= f.count(0)
    z=z.min()
#     z['bidder_id']=data['bidder_id']
#     print z
    return z

# %%
def handle_drop_data(train_data,all_data):
    train_data=train_data.drop('address',axis=1)
#     train_data=train_data.drop('payment_account',axis=1)
    train_data=train_data.drop('bidder_id',axis=1)
    return train_data

# %%
def features_engineering(train_data,all_data):
    train_data=handle_acution_num(train_data,all_data)
    train_data=handle_merchandise_num(train_data,all_data)
    train_data=handle_country_num(train_data,all_data)   
    train_data=handle_device_num(train_data,all_data)       
    train_data=handle_ip_num(train_data,all_data)
    train_data=handle_url_num(train_data,all_data)
    train_data=handle_drop_data(train_data,all_data)
    return train_data

# %%
all_data.head()
# Out:
#    bid_id                              bidder_id auction merchandise  device  \
# 0       0  8dac2b259fd1c6d1120e519fb1ac14fbqvax8   ewmzr     jewelry  phone0
# 1       1  668d393e858e8126275433046bbd35c6tywop   aeqok   furniture  phone1
# 2       2  aa5f360084278b35d746fa6af3a7a1a5ra3xe   wa00e  home goods  phone2
# 3       3  3939ac3ef7d472a59a9c5f893dd3e39fh9ofi   jefix     jewelry  phone4
# 4       4  8393c48eaf4b8fa96886edc7cf27b372dsibi   jefix     jewelry  phone5
#
#                time country              ip              url  \
# 0  9759243157894736      us   69.166.231.58  vasstdc27m7nks3
# 1  9759243157894736      in   50.201.125.84  jmqlhflrzwuay9c
# 2  9759243157894736      py  112.54.208.157  vasstdc27m7nks3
# 3  9759243157894736      in   18.99.175.133  vasstdc27m7nks3
# 4  9759243157894736      in    145.138.5.37  vasstdc27m7nks3
#
#                                  address  \
# 0  7f4c6ac489cbd95e38e4f093bb308af5jae25
# 1  42a3b61a1fe69d66ad60f3e347aa09b1erfe2
# ...

# %%
#特征工程
fit_data=features_engineering(merge_data,all_data)

# %%
fit_data.head()
# Out:
#                                                              payment_account  \
# bidder_id
# 91a3c57b13234af24875c56fb7e2b2f4rb56a  a3d2de7675556553a5f08e4c88d2c228754av
# 624f258b49e77713fc34034560f93fb3hu3jo  a3d2de7675556553a5f08e4c88d2c228v1sga
# 1c5f4fc669099bfbfac515cd26997bd12ruaj  a3d2de7675556553a5f08e4c88d2c2280cybl
# 4bee9aba2abda51bf43d639013d6efe12iycd  51d80e233f7b6a7dfdee484a3c120f3b2ita8
# 4ab12bc61c82ddd9c2d65e60555808acqgos1  a3d2de7675556553a5f08e4c88d2c22857ddh
#
#                                        outcome  max_auction_num  \
# bidder_id
# 91a3c57b13234af24875c56fb7e2b2f4rb56a      0.0              3.0
# 624f258b49e77713fc34034560f93fb3hu3jo      0.0              3.0
# 1c5f4fc669099bfbfac515cd26997bd12ruaj      0.0              1.0
# 4bee9aba2abda51bf43d639013d6efe12iycd      0.0              1.0
# 4ab12bc61c82ddd9c2d65e60555808acqgos1      0.0             38.0
#
#                                        min_auction_num  per_auction_num  \
# bidder_id
# ...

# %% [markdown]
# 由于用户数据存在字符串特征，我们需先将其数值化，通过labelEncoder对每一列数据进行数值化处理。

# %%
def preprocess_features(X):
    ''' 预处理特征数据，将字符串数据数值化
    '''
    labelEncoder=None
    # 初始化一个用于输出的DataFrame
    output = pd.DataFrame(index = X.index)

    # 查看数据的每一个特征列
    for col, col_data in X.iteritems():
        
        # 如果数据类型是类别的（categorical），将它转换成虚拟变量
        if col_data.dtype == object:
            if col=='bidder_id':
                labelEncoder=LabelEncoder()
                col_data = labelEncoder.fit_transform(col_data)
            else :
                col_data = LabelEncoder().fit_transform(col_data)
            #col_data=OneHotEncoder( sparse=False ).fit_transform(a.reshape(-1,1)) 
            #LabelBinarizer().fit_transform(X[col])
            col_data=pd.DataFrame(col_data,columns=[col])
            col_data.index=X.index
        # 收集转换后的列
        output = output.join(col_data)
    return output,labelEncoder

# %%
merge_data_pross,labelEncoder = preprocess_features(merge_data)

# %%
merge_data_pross[pd.isnull(merge_data_pross.outcome)].shape
# Out:
# (4700, 28)

# %% [markdown]
# ## 实施

# %% [markdown]
# 随后，在用户数据中分离出训练数据以及预测数据

# %%
def extract_data(all_data): 
    
    #y_all=all_data[['outcome']]
    #X_all = all_data.drop('outcome',1)
    # 提取特征列
    feature_cols = list(all_data.columns[:])
    feature_cols.remove('outcome')

    # 提取目标列 ‘passed’
    target_col = 'outcome'
    
    # 显示列的列表
    print "Feature columns:\n{}".format(feature_cols)
    print "\nTarget column: {}".format(target_col)

    # 将数据分割成特征数据和目标数据（即X_all 和 y_all）
    X_all = all_data[feature_cols]
    y_all = all_data[target_col]

    # 通过打印前5行显示特征信息
    print "\nFeature values:"
    print X_all.shape
    return X_all,y_all

# %%
predict_data=merge_data_pross[pd.isnull(merge_data_pross.outcome)]
fit_data_pross=merge_data_pross.drop(predict_data.index)
X_all,y_all= extract_data(fit_data_pross)
X_predict=predict_data.drop('outcome',1)
# Out:
# Feature columns:
# ['address', 'bidder_id', 'payment_account', 'max_auction_num', 'min_auction_num', 'per_auction_num', 'count_auction_num', 'count_auction_std', 'count_auction_max', 'count_auction_time_mean', 'count_auction_time_min', 'count_auction_time_max', 'max_merchandise_num', 'mean_merchandise_num', 'count_country', 'count_auction_mean_country', 'count_auction_max_country', 'mean_device_num', 'max_device_num', 'count_device', 'mean_auction_ip', 'max_auction_ip', 'count_ip', 'mean_auction_url_num', 'mean_url_num', 'max_url_num', 'min_url_num']
#
# Target column: outcome
#
# Feature values:
# (2013, 27)

# %%
predict_data
# Out:
#                                        address  bidder_id  payment_account  \
# bidder_id
# 49bb5a3c944b8fc337981cc7a9ccae41u31d7     1958       1952             3761
# a921612b85a1494456e74c09393ccb65ylp4y     4135       4447             4780
# 6b601e72a4d264dab9ace9d7b229b47479v6i     3785       2833             1806
# eaf0ed0afc9689779417274b4791726cn5udi     5063       6179             4321
# cdecd8d02ed8c6037e38042c7745f688mx5sf     5411       5427             3382
# d4aed439bdc854a56fc6cc3bdb986775w7hxw     3080       5573             5106
# ed591299b162a19ff77f0479495831b31hl1q     4057       6245             3370
# eebdee08b0f67283126ef60307f49680sb9va     2366       6275              976
# 6887f0abc4eb4c79eb0e23c48ceea186vjfih      510       2742             5169
# 37eb6e2979e66d4ce29a74ac1c8bc6a5lqs6t      808       1454             2364
# 3bdce1c10890630c287cc3f758ae0dc3ddpu8      586       1542             1436
# ...

# %% [markdown]
# 分离出测试数据集合

# %%
# TODO：设置测试集的数量
num_test = 0.2

# TODO：把数据集混洗和分割成上面定义的训练集和测试集
X_train, X_test, y_train, y_test = train_test_split(X_all, y_all, test_size=num_test, random_state=0)

print "Training set has {} samples.".format(X_train.shape[0])
print "Testing set has {} samples.".format(X_test.shape[0])
# Out:
# Training set has 1610 samples.
# Testing set has 403 samples.

# %% [markdown]
# 我们选择RandomForest、lightGBM、Xgboost三个分类器进行训练，同时也使用ensemble方法把三个分类器进行合并得到一个新的分类起，使用相同的训练数据及测试数据，并通过指标AUC及Time进行分类器评估。

# %%
def predict_labels_auc(clf, features, target):
    '''用训练好的分类器做预测并输出auc值'''
    
    from sklearn.metrics import roc_auc_score
#     start = time()
    probas_ = clf.predict_proba(features)
#     end = time()
    return roc_auc_score(target, probas_[:, 1])

def eval_predict(clf, X_train, y_train, X_test, y_test):
    # 训练一个分类器
    train_classifier(clf, X_train, y_train)
    
    auc_score_train = predict_labels_auc(clf, X_train, y_train)
    auc_score_test = predict_labels_auc(clf, X_test, y_test)
    
    return auc_score_test

# %%
def train_classifier(clf, X_train, y_train):
    clf.fit(X_train, y_train)

def predict_labels_auc_time(clf, features, target):
    ''' 用训练好的分类器做预测并输出auc值'''
    from sklearn.metrics import roc_auc_score
    start = time()
    probas_ = clf.predict_proba(features)
    end = time()
    return roc_auc_score(target, probas_[:, 1]),end-start

def train_predict(clf, X_train, y_train, X_test, y_test):
    
    # 训练一个分类器
    train_classifier(clf, X_train, y_train)
    
    auc_score_train, train_time = predict_labels_auc_time(clf, X_train, y_train)
    auc_score_test, test_time = predict_labels_auc_time(clf, X_test, y_test)
    
    # 输出训练和测试的预测结果
    print "| {:} | {:.4f} | {:.4f} | {:.4f} | {:.4f} |".format(X_train.shape[0], train_time, test_time, auc_score_train,auc_score_test)

# %% [markdown]
# 使用同样的训练集对xgboost、lightgbm、randamforest三种模型做训练，并通过对训练时间、预测时间、训练AUC、测试AUC的对比，选择最优的模型当作最终使用的模型，分类器参数都为默认值。

# %%
import lightgbm as lgb
# TODO：初始化三个模型
clf_A = RandomForestClassifier(random_state=1)
clf_B = lgb.LGBMClassifier()
# clf_B = xgb.XGBClassifier()
clf_C = xgb.XGBClassifier()

clf_D = VotingClassifier(estimators=[('rd', clf_A), ('lightgbm', clf_B), ('xgboost', clf_C)], voting='soft', weights=[1,2,2])

        
clfs = [clf_A, clf_B, clf_C,clf_D]

dSize=X_train.shape[0]
#3071224
for i, clf in enumerate(clfs):
    print "** 分类器 {} - {} **".format(clf.__class__, i)
    print ''
    print "| 训练集大小 | 训练时间（Time） | 预测时间 (测试) | AUC值 (训练) | AUC值 (测试) |"
    print "| :----: | :----: | :----: | :----: | :----: |"
    for Size in [dSize/10, dSize/5,dSize/2, dSize]:
        train_predict(clf, X_train[:Size], y_train[:Size], X_test, y_test)
    print ''
# Out:
# ** 分类器 <class 'sklearn.ensemble.forest.RandomForestClassifier'> - 0 **
#
# | 训练集大小 | 训练时间（Time） | 预测时间 (测试) | AUC值 (训练) | AUC值 (测试) |
# | :----: | :----: | :----: | :----: | :----: |
# | 161 | 0.0075 | 0.0073 | 1.0000 | 0.8632 |
# | 322 | 0.0065 | 0.0078 | 1.0000 | 0.7939 |
# | 805 | 0.0069 | 0.0062 | 0.9994 | 0.8067 |
# | 1610 | 0.0078 | 0.0062 | 0.9997 | 0.8093 |
#
# ** 分类器 <class 'lightgbm.sklearn.LGBMClassifier'> - 1 **
#
# | 训练集大小 | 训练时间（Time） | 预测时间 (测试) | AUC值 (训练) | AUC值 (测试) |
# | :----: | :----: | :----: | :----: | :----: |
# | 161 | 0.0033 | 0.0051 | 0.9306 | 0.8906 |
# | 322 | 0.0031 | 0.0023 | 0.9755 | 0.8747 |
# | 805 | 0.0072 | 0.0100 | 0.9807 | 0.8283 |
# | 1610 | 0.0037 | 0.0060 | 0.9831 | 0.8898 |
#
# ** 分类器 <class 'xgboost.sklearn.XGBClassifier'> - 2 **
#
# | 训练集大小 | 训练时间（Time） | 预测时间 (测试) | AUC值 (训练) | AUC值 (测试) |
# | :----: | :----: | :----: | :----: | :----: |
# | 161 | 0.0046 | 0.0012 | 0.9988 | 0.8241 |
# | 322 | 0.0080 | 0.0018 | 0.9996 | 0.8158 |
# ...

# %% [markdown]
# 由上方数据可见，XGBClassifier训练时间最快，其次为LGBMClassifier，RandomForestClassifier训练时间较长。
#
# 在AUC值上，其次是LGBMClassifier预测分数为0.8898，分数最高，其次是XGBClassifier，分数为0.8735,最低为RandomForestClassifier，分数为0.8093。
#
# 我们也使用了ensemble方法来集成三个分类器，但其测试auc为0.8700，效果并不如XGBClassifier。
#
# 综上我们选取XGBClassifier作为最终模型。

# %% [markdown]
# ## 改进

# %%
# def modelfit(alg, X_train, y_train,X_test,y_test,useTrainCV=True, cv_folds=5, early_stopping_rounds=50):
#     from sklearn.metrics import accuracy_score
#     from sklearn.metrics import roc_auc_score
#     if useTrainCV:
#         xgb_param = alg.get_xgb_params()
#         xgtrain = xgb.DMatrix(X_train, label=y_train)
#         cvresult = xgb.cv(xgb_param, xgtrain, num_boost_round=alg.get_params()['n_estimators'], nfold=cv_folds,
#             metrics='auc', early_stopping_rounds=early_stopping_rounds,verbose_eval=False)
#         alg.set_params(n_estimators=cvresult.shape[0])
# #         print cvresult.mean()
    
#     #Fit the algorithm on the data
#     alg.fit(X_train, y_train,eval_metric='auc')
        
#     #Predict training set:
#     dtrain_predictions = alg.predict(X_train)
#     dtrain_predprob = alg.predict_proba(X_train)[:,1]
#     dtest_predprob = alg.predict_proba(X_test)[:,1]
        
#     #Print model report:
#     print "\nModel Report"
#     print "Accuracy : %.4g" % accuracy_score(y_train, dtrain_predictions)
#     print "AUC Score (Train): %f" % roc_auc_score(y_train, dtrain_predprob)
#     print "AUC Score (Test): %f" % roc_auc_score(y_test, dtest_predprob)
    
#     feat_imp = pd.Series(alg.booster().get_fscore()).sort_values(ascending=False)
#     feat_imp.plot(kind='bar', title='Feature Importances')
#     plt.ylabel('Feature Importance Score')
    
    
def modelfit(alg, X_train, y_train,useTrainCV=True, cv_folds=5, early_stopping_rounds=50):
    from sklearn.metrics import accuracy_score
    from sklearn.metrics import roc_auc_score
    if useTrainCV:
        xgb_param = alg.get_xgb_params()
        xgtrain = xgb.DMatrix(X_train, label=y_train)
        cvresult = xgb.cv(xgb_param, xgtrain, num_boost_round=alg.get_params()['n_estimators'], nfold=cv_folds,
            metrics='auc', early_stopping_rounds=early_stopping_rounds,verbose_eval=False)
        alg.set_params(n_estimators=cvresult.shape[0])
#         print cvresult.mean()
    
    #Fit the algorithm on the data
    alg.fit(X_train, y_train,eval_metric='auc')
        
    #Predict training set:
    dtrain_predictions = alg.predict(X_train)
    dtrain_predprob = alg.predict_proba(X_train)[:,1]
    dtest_predprob = alg.predict_proba(X_test)[:,1]
        
    #Print model report:
    print "\nModel Report"
    print "Accuracy : %.4g" % accuracy_score(y_train, dtrain_predictions)
    print "AUC Score (Train): %f" % roc_auc_score(y_train, dtrain_predprob)
#     print "AUC Score (Test): %f" % roc_auc_score(y_test, dtest_predprob)
    
    feat_imp = pd.Series(alg.booster().get_fscore()).sort_values(ascending=False)
    feat_imp.plot(kind='bar', title='Feature Importances')
    plt.ylabel('Feature Importance Score')

# %% [markdown]
# #### xgboost 调参

# %%
xgb1 =xgb.XGBClassifier()
modelfit(xgb1, X_all, y_all)
# Out:
# Model Report
# Accuracy : 0.9846
# AUC Score (Train): 0.988952

# %% [markdown]
# 我将通过GridSearchCV对xgboost进行参数优化

# %% [markdown]
# - max_depth 和 min_weight 参数调优

# %%
param_test1 = {
 'max_depth':range(1,5,1),
 'min_child_weight':range(10,15,1),
}
gsearch1 = GridSearchCV(estimator = xgb.XGBClassifier(), 
 param_grid = param_test1,     scoring='roc_auc',iid=False, cv=5)
# gsearch1.fit(X_train,y_train)
gsearch1.fit(X_all,y_all)
print pd.DataFrame(gsearch1.cv_results_['mean_test_score'],gsearch1.cv_results_['params'])
print gsearch1.best_score_,gsearch1.best_params_,
# Out:
#                                                    0
# {u'max_depth': 1, u'min_child_weight': 10}  0.907416
# {u'max_depth': 1, u'min_child_weight': 11}  0.907218
# {u'max_depth': 1, u'min_child_weight': 12}  0.906890
# {u'max_depth': 1, u'min_child_weight': 13}  0.907420
# {u'max_depth': 1, u'min_child_weight': 14}  0.907176
# {u'max_depth': 2, u'min_child_weight': 10}  0.916890
# {u'max_depth': 2, u'min_child_weight': 11}  0.917622
# {u'max_depth': 2, u'min_child_weight': 12}  0.918426
# {u'max_depth': 2, u'min_child_weight': 13}  0.915922
# {u'max_depth': 2, u'min_child_weight': 14}  0.916563
# {u'max_depth': 3, u'min_child_weight': 10}  0.916439
# {u'max_depth': 3, u'min_child_weight': 11}  0.917830
# {u'max_depth': 3, u'min_child_weight': 12}  0.918861
# {u'max_depth': 3, u'min_child_weight': 13}  0.913487
# {u'max_depth': 3, u'min_child_weight': 14}  0.915363
# {u'max_depth': 4, u'min_child_weight': 10}  0.916831
# {u'max_depth': 4, u'min_child_weight': 11}  0.917312
# ...

# %%
# modelfit(gsearch1.best_estimator_, X_train,y_train,X_test,y_test)
modelfit(gsearch1.best_estimator_, X_all,y_all)
# Out:
# Model Report
# Accuracy : 0.9712
# AUC Score (Train): 0.967730

# %% [markdown]
# - gamma参数调优

# %%
param_test2 = {
 'gamma':range(0,10,1),
}
# gsearch2 = GridSearchCV(estimator = xgb.XGBClassifier(max_depth=4, min_child_weight= 12), 
gsearch2 = GridSearchCV(estimator = xgb.XGBClassifier(max_depth=3, min_child_weight= 12), 
 param_grid = param_test2,     scoring='roc_auc',iid=False, cv=5)
# gsearch1.fit(X_train,y_train)
gsearch2.fit(X_all,y_all)
print pd.DataFrame(gsearch2.cv_results_['mean_test_score'],gsearch2.cv_results_['params'])
print gsearch2.best_score_,gsearch2.best_params_,
# Out:
#                       0
# {u'gamma': 0}  0.918861
# {u'gamma': 1}  0.917970
# {u'gamma': 2}  0.917436
# {u'gamma': 3}  0.912832
# {u'gamma': 4}  0.903827
# {u'gamma': 5}  0.899837
# {u'gamma': 6}  0.902503
# {u'gamma': 7}  0.899751
# {u'gamma': 8}  0.900419
# {u'gamma': 9}  0.899859
# 0.918861256545 {'gamma': 0}

# %%
# modelfit(gsearch2.best_estimator_, X_train,y_train,X_test,y_test)

modelfit(gsearch2.best_estimator_, X_all,y_all)
# Out:
# Model Report
# Accuracy : 0.9712
# AUC Score (Train): 0.967730

# %% [markdown]
# - 调整subsample 和 colsample_bytree 参数

# %%
param_test3 = {
#   'subsample':[i/10.0 for i in range(5,11)],
#   'colsample_bytree':[i/10.0 for i in range(5,11)]
      'subsample':[i/100.0 for i in range(90,101)],
 'colsample_bytree':[i/100.0 for i in range(65,75)]
}

gsearch3 = GridSearchCV(estimator = xgb.XGBClassifier(max_depth= 3, min_child_weight= 12,gamma=0), 
 param_grid = param_test3,     scoring='roc_auc',iid=False, cv=5)

gsearch3.fit(X_train,y_train)
print pd.DataFrame(gsearch3.cv_results_['mean_test_score'],gsearch3.cv_results_['params'])
print gsearch3.best_score_,gsearch3.best_params_,
# Out:
#                                                         0
# {u'subsample': 0.9, u'colsample_bytree': 0.65}   0.913808
# {u'subsample': 0.91, u'colsample_bytree': 0.65}  0.917121
# {u'subsample': 0.92, u'colsample_bytree': 0.65}  0.917764
# {u'subsample': 0.93, u'colsample_bytree': 0.65}  0.916103
# {u'subsample': 0.94, u'colsample_bytree': 0.65}  0.915433
# {u'subsample': 0.95, u'colsample_bytree': 0.65}  0.913328
# {u'subsample': 0.96, u'colsample_bytree': 0.65}  0.911754
# {u'subsample': 0.97, u'colsample_bytree': 0.65}  0.913379
# {u'subsample': 0.98, u'colsample_bytree': 0.65}  0.915226
# {u'subsample': 0.99, u'colsample_bytree': 0.65}  0.913890
# {u'subsample': 1.0, u'colsample_bytree': 0.65}   0.918478
# {u'subsample': 0.9, u'colsample_bytree': 0.66}   0.913808
# {u'subsample': 0.91, u'colsample_bytree': 0.66}  0.917121
# {u'subsample': 0.92, u'colsample_bytree': 0.66}  0.917764
# {u'subsample': 0.93, u'colsample_bytree': 0.66}  0.916103
# ...

# %%
# modelfit(gsearch3.best_estimator_, X_train,y_train,X_test,y_test)
modelfit(gsearch3.best_estimator_, X_all,y_all)
# print gsearch3.best_estimator_
# Out:
# Model Report
# Accuracy : 0.9647
# AUC Score (Train): 0.960390

# %% [markdown]
# - 调整 reg_alpha 参数

# %%
param_test4 = {
#  'reg_alpha':[0,1e-5, 1e-2, 0.1, 1, 100]
#     'reg_alpha':np.linspace(0,5, 20),
#        'reg_alpha': range(0,10,1),
#          'reg_alpha':[i/100.0 for i in range(1,50)]
#         'reg_alpha':[i/100.0 for i in range(1,50)]
      'reg_alpha':[i/100.0 for i in range(30,40)],

}
gsearch4 = GridSearchCV(estimator = xgb.XGBClassifier(max_depth= 3, min_child_weight= 12,gamma=0,subsample=1.0, colsample_bytree= 0.65), 
 param_grid = param_test4,     scoring='roc_auc',n_jobs=4,iid=False, cv=5)

gsearch4.fit(X_all,y_all)
print pd.DataFrame(gsearch4.cv_results_['mean_test_score'],gsearch4.cv_results_['params'])
print gsearch4.best_score_,gsearch4.best_params_,
# Out:
#                              0
# {u'reg_alpha': 0.3}   0.915894
# {u'reg_alpha': 0.31}  0.917254
# {u'reg_alpha': 0.32}  0.919465
# {u'reg_alpha': 0.33}  0.918825
# {u'reg_alpha': 0.34}  0.918041
# {u'reg_alpha': 0.35}  0.917187
# {u'reg_alpha': 0.36}  0.919269
# {u'reg_alpha': 0.37}  0.918097
# {u'reg_alpha': 0.38}  0.919506
# {u'reg_alpha': 0.39}  0.920227
# 0.920226876091 {'reg_alpha': 0.39}

# %%
# modelfit(gsearch4.best_estimator_, X_train,y_train,X_test,y_test)
modelfit(gsearch4.best_estimator_, X_all,y_all)
print gsearch4.best_estimator_
# Out:
# Model Report
# Accuracy : 0.9647
# AUC Score (Train): 0.960390
# XGBClassifier(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.45,
#        gamma=0, learning_rate=0.1, max_delta_step=0, max_depth=3,
#        min_child_weight=12, missing=None, n_estimators=100, nthread=-1,
#        objective='binary:logistic', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=0, silent=True, subsample=0.82)

# %% [markdown]
# - 调整 learning_rate 参数

# %%
param_test5 = {
#  'learning_rate':np.linspace(0.01,0.5, 10),
     'learning_rate':[i/100.0 for i in range(0,15)]

#     'n_estimators':[100,1000,5000]
}
gsearch5 = GridSearchCV(estimator = xgb.XGBClassifier(max_depth= 3, min_child_weight= 12,gamma=0,subsample=1.0, colsample_bytree= 0.65,reg_alpha=0.39), 
 param_grid = param_test5,     scoring='roc_auc',n_jobs=4,iid=False, cv=5)

gsearch5.fit(X_all,y_all)

print pd.DataFrame(gsearch5.cv_results_['mean_test_score'],gsearch5.cv_results_['params'])
print gsearch5.best_score_,gsearch5.best_params_,
# Out:
#                                  0
# {u'learning_rate': 0.0}   0.500000
# {u'learning_rate': 0.01}  0.895023
# {u'learning_rate': 0.02}  0.898373
# {u'learning_rate': 0.03}  0.900304
# {u'learning_rate': 0.04}  0.904043
# {u'learning_rate': 0.05}  0.912312
# {u'learning_rate': 0.06}  0.913301
# {u'learning_rate': 0.07}  0.917432
# {u'learning_rate': 0.08}  0.918432
# {u'learning_rate': 0.09}  0.917465
# {u'learning_rate': 0.1}   0.920227
# {u'learning_rate': 0.11}  0.917387
# {u'learning_rate': 0.12}  0.914916
# {u'learning_rate': 0.13}  0.916874
# {u'learning_rate': 0.14}  0.918149
# 0.920226876091 {'learning_rate': 0.1}

# %%
# modelfit(gsearch5.best_estimator_, X_train,y_train,X_test,y_test)
modelfit(gsearch5.best_estimator_, X_all,y_all)
# Out:
# Model Report
# Accuracy : 0.9677
# AUC Score (Train): 0.963651

# %%
xgb6 = xgb.XGBClassifier(max_depth= 3, min_child_weight= 12,gamma=0,subsample=1.0, colsample_bytree= 0.65,reg_alpha=0.39,learning_rate=0.1)
# modelfit(xgb6, X_train,y_train,X_test,y_test)
modelfit(xgb6, X_all,y_all)
# Out:
# Model Report
# Accuracy : 0.9692
# AUC Score (Train): 0.966421

# %% [markdown]
# #### Lightgbm 调参

# %%
param_test1 = {
 'num_leaves':range(2,1000,30),
 'min_child_weight':range(1,15,1),
}
gsearch1 = GridSearchCV(estimator = lgb.LGBMClassifier(), 
 param_grid = param_test1,     scoring='roc_auc',iid=False, cv=5)
# gsearch1.fit(X_train,y_train)
gsearch1.fit(X_all,y_all)
print pd.DataFrame(gsearch1.cv_results_['mean_test_score'],gsearch1.cv_results_['params'])
print gsearch1.best_score_,gsearch1.best_params_,
# Out:
#                                                       0
# {u'num_leaves': 2, u'min_child_weight': 1}     0.866065
# {u'num_leaves': 32, u'min_child_weight': 1}    0.843760
# {u'num_leaves': 62, u'min_child_weight': 1}    0.853146
# {u'num_leaves': 92, u'min_child_weight': 1}    0.851936
# {u'num_leaves': 122, u'min_child_weight': 1}   0.854213
# {u'num_leaves': 152, u'min_child_weight': 1}   0.854275
# {u'num_leaves': 182, u'min_child_weight': 1}   0.854275
# {u'num_leaves': 212, u'min_child_weight': 1}   0.854275
# {u'num_leaves': 242, u'min_child_weight': 1}   0.854275
# {u'num_leaves': 272, u'min_child_weight': 1}   0.854275
# {u'num_leaves': 302, u'min_child_weight': 1}   0.854275
# {u'num_leaves': 332, u'min_child_weight': 1}   0.854275
# {u'num_leaves': 362, u'min_child_weight': 1}   0.854275
# {u'num_leaves': 392, u'min_child_weight': 1}   0.854275
# {u'num_leaves': 422, u'min_child_weight': 1}   0.854275
# {u'num_leaves': 452, u'min_child_weight': 1}   0.854275
# ...

# %%
param_test2 = {
 'max_bin':range(600,700,5),
}
# gsearch2 = GridSearchCV(estimator = xgb.XGBClassifier(max_depth=4, min_child_weight= 12), 
gsearch2 = GridSearchCV(estimator = lgb.LGBMClassifier(num_leaves=32, min_child_weight= 6), 
 param_grid = param_test2,     scoring='roc_auc',iid=False, cv=5)
# gsearch1.fit(X_train,y_train)
gsearch2.fit(X_all,y_all)
print pd.DataFrame(gsearch2.cv_results_['mean_test_score'],gsearch2.cv_results_['params'])
print gsearch2.best_score_,gsearch2.best_params_,
# Out:
#                           0
# {u'max_bin': 600}  0.910009
# {u'max_bin': 605}  0.910009
# {u'max_bin': 610}  0.910009
# {u'max_bin': 615}  0.910009
# {u'max_bin': 620}  0.910009
# {u'max_bin': 625}  0.910009
# {u'max_bin': 630}  0.910009
# {u'max_bin': 635}  0.910122
# {u'max_bin': 640}  0.909416
# {u'max_bin': 645}  0.909441
# {u'max_bin': 650}  0.910462
# {u'max_bin': 655}  0.910462
# {u'max_bin': 660}  0.910462
# {u'max_bin': 665}  0.906430
# {u'max_bin': 670}  0.907368
# {u'max_bin': 675}  0.907368
# {u'max_bin': 680}  0.907368
# {u'max_bin': 685}  0.907368
# {u'max_bin': 690}  0.907368
# {u'max_bin': 695}  0.906408
# 0.910461854899 {'max_bin': 650}

# %%
param_test3 = {
#   'subsample':[i/10.0 for i in range(5,11)],
#   'colsample_bytree':[i/10.0 for i in range(5,11)]
      'subsample':[i/100.0 for i in range(60,80)],
 'colsample_bytree':[i/100.0 for i in range(50,70)]
}

gsearch3 = GridSearchCV(estimator = lgb.LGBMClassifier(num_leaves=32, min_child_weight= 6,max_bin=650), 
 param_grid = param_test3,     scoring='roc_auc',iid=False, cv=5)

gsearch3.fit(X_train,y_train)
print pd.DataFrame(gsearch3.cv_results_['mean_test_score'],gsearch3.cv_results_['params'])
print gsearch3.best_score_,gsearch3.best_params_,
# Out:
#                                                         0
# {u'subsample': 0.6, u'colsample_bytree': 0.5}    0.911374
# {u'subsample': 0.61, u'colsample_bytree': 0.5}   0.910742
# {u'subsample': 0.62, u'colsample_bytree': 0.5}   0.915448
# {u'subsample': 0.63, u'colsample_bytree': 0.5}   0.920840
# {u'subsample': 0.64, u'colsample_bytree': 0.5}   0.916245
# {u'subsample': 0.65, u'colsample_bytree': 0.5}   0.915249
# {u'subsample': 0.66, u'colsample_bytree': 0.5}   0.913182
# {u'subsample': 0.67, u'colsample_bytree': 0.5}   0.914616
# {u'subsample': 0.68, u'colsample_bytree': 0.5}   0.914291
# {u'subsample': 0.69, u'colsample_bytree': 0.5}   0.916122
# {u'subsample': 0.7, u'colsample_bytree': 0.5}    0.917975
# {u'subsample': 0.71, u'colsample_bytree': 0.5}   0.922045
# {u'subsample': 0.72, u'colsample_bytree': 0.5}   0.918396
# {u'subsample': 0.73, u'colsample_bytree': 0.5}   0.916347
# {u'subsample': 0.74, u'colsample_bytree': 0.5}   0.920241
# ...

# %%
# param_test4 = {
# #  'reg_alpha':[0,1e-5, 1e-2, 0.1, 1, 100]
# #     'reg_alpha':np.linspace(0,5, 20),
#    'reg_alpha': range(0,5,5),
# #          'reg_alpha':[i/10.0 for i in range(1,50)]

# #       'reg_alpha':[i/100.0 for i in range(20,50)],

# }
# gsearch4 = GridSearchCV(estimator = lgb.LGBMClassifier(num_leaves=32, min_child_weight= 6,max_bin=650,subsample=0.79,colsample_bytree=0.56), 
#  param_grid = param_test4,     scoring='roc_auc',n_jobs=4,iid=False, cv=5)

# gsearch4.fit(X_all,y_all)
# print pd.DataFrame(gsearch4.cv_results_['mean_test_score'],gsearch4.cv_results_['params'])
# print gsearch4.best_score_,gsearch4.best_params_,

# %%
param_test5 = {
#  'learning_rate':np.linspace(0.01,0.5, 10),
     'learning_rate':[i/100.0 for i in range(0,20)]

#     'n_estimators':[100,1000,5000]
}
gsearch5 = GridSearchCV(estimator = xgb.XGBClassifier(max_depth= 3, min_child_weight= 12,gamma=0,subsample=0.87, colsample_bytree= 0.45,reg_alpha=1.0526), 
 param_grid = param_test5,     scoring='roc_auc',n_jobs=4,iid=False, cv=5)

gsearch5.fit(X_all,y_all)

print pd.DataFrame(gsearch5.cv_results_['mean_test_score'],gsearch5.cv_results_['params'])
print gsearch5.best_score_,gsearch5.best_params_,

# %% [markdown]
# # 结果

# %% [markdown]
# ## 模型评估与验证

# %% [markdown]
# 其次我们将展示模型参数learning_rate对模型分数及方差偏差的影响。

# %%
def PlotCurve(clf,X, y,param_name,param_range):
    """ Calculates the performance of the model as model complexity increases.
        The learning and testing errors rates are then plotted. """
    import sklearn.model_selection as curves
    import matplotlib.pyplot as pl

    # Calculate the training and testing scores
    train_scores, test_scores = curves.validation_curve(clf, X, y,param_name = param_name, param_range = param_range, cv = 10, scoring = 'roc_auc')

    # Find the mean and standard deviation for smoothing
    train_mean = np.mean(train_scores, axis=1)
    train_std = np.std(train_scores, axis=1)
    test_mean = np.mean(test_scores, axis=1)
    test_std = np.std(test_scores, axis=1)

    # Plot the validation curve
    pl.figure(figsize=(7, 5))
    pl.title('Xgboost Complexity Performance')
    pl.plot(param_range, train_mean, 'o-', color = 'r', label = 'Training Score')
    pl.plot(param_range, test_mean, 'o-', color = 'g', label = 'Validation Score')
    pl.fill_between(param_range, train_mean - train_std, \
        train_mean + train_std, alpha = 0.15, color = 'r')
    pl.fill_between(param_range, test_mean - test_std, \
        test_mean + test_std, alpha = 0.15, color = 'g')
    
    # Visual aesthetics
    pl.legend(loc = 'lower right')
    pl.xlabel(param_name)
    pl.ylabel('AUC_Score')
    pl.ylim([-0.05,1.05])
    pl.show()
    
clf = xgb.XGBClassifier(max_depth= 3, min_child_weight= 12,gamma=0,subsample=1.0, colsample_bytree= 0.65,reg_alpha=0.39)
PlotCurve(clf,X_all,y_all,'learning_rate',np.linspace(0.01,1, 30))
# PlotCurve(clf,X_all,y_all,'colsample_bylevel',np.arange(1, 20,5))
# PlotCurve(clf,X_all,y_all,'colsample_bytree',np.arange(1,20))

# %% [markdown]
# 如图可知，learning_rate在0.1之前auc随着learning_rate的升高而升高，存在较小的偏差。到达01之后，随着learning_rate继续提高，训练auc与测试auc差距逐渐变大，测试auc越来越小，方差越来越高。可见learning_rate=0.1时方差最小，偏差相对较小，是最优参数。

# %% [markdown]
# 下面我们将展现不同的训练集对测试auc及训练auc的影响

# %%
def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None,
                        train_sizes=np.linspace(0.1, 1.0, 10)):
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv,train_sizes=train_sizes,scoring='roc_auc')
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")

    plt.legend(loc="best")
    return plt

title = "Xgboost Learning Curves "
# clf=xgb.XGBClassifier(learning_rate=0.03)
# clf=xgb.XGBClassifier(min_child_weight=13)
clf = xgb.XGBClassifier(max_depth= 3, min_child_weight= 12,gamma=0,subsample=1.0, colsample_bytree= 0.65,reg_alpha=0.39,learning_rate=0.1)

plot_learning_curve(clf, title, X_all, y_all, (0.0, 1.01), cv=10)

plt.show()

# %% [markdown]
# 从上图中可看到，auc分数初期随着训练集数量增多而提高，方差较小，训练集到达600左右开始趋于稳定。此时的训练auc与测试auc方差变小，偏差随着训练集合的增多而降低。

# %% [markdown]
# ## 理由

# %% [markdown]
# 我们在kaggle提交的最终分数私榜分数为0.929，达到了我们的预期。

# %% [markdown]
# ![](imgs/kaggle_score.png)

# %% [markdown]
# # 结论

# %% [markdown]
# ## 自由形态的可视化

# %% [markdown]
# 我们统计了机器人和真实用户按照按时间分布的竞拍次数，呈现在下图中，从图中可见，竞拍集中在三个时间段内，其他时间段内都没有竞拍行为，有两种可能性，一为网站的竞拍活动有周期性，有时间间隔。二为网站提供的数据经过了认为的筛选处理过。

# %%
bots=explo_data[(explo_data['outcome']==1)]['time']
mans=explo_data[(explo_data['outcome']==0)]['time']

# print bots
sns.distplot(bots,bins=200,color='r')
sns.distplot(mans,bins=200,color='b')

# %% [markdown]
# 放大观察其中一个时间段，蓝色为真实用户，红色为机器人用户，从曲线分布中可看到真是用户竞拍行为有明显的周期性，可能是与生活作息有关。相较之下机器人的行为分布曲线很平缓。如果进行优化，我们可基于真实用户的周期性做特征统计，进一步提高精度。

# %%
bots=explo_data[(explo_data['outcome']==1)&(explo_data['time']<9.73*1e15)&(explo_data['time']>9.66*1e15)]['time']
mans=explo_data[(explo_data['outcome']==0)&(explo_data['time']<9.73*1e15)&(explo_data['time']>9.66*1e15)]['time']
# print bots
sns.distplot(bots,bins=200,color='r')
sns.distplot(mans,bins=200,color='b')

# %% [markdown]
# 下面我们将列出xgboost模型中影响最高的特征。下图中可见，影响力最高的前三个特征分别是：'每个用户平均通过一个url的进行的竞拍次数'、‘每个用户一次拍卖中的平均竞拍次数’、'每个用户在平台上竞拍商品类型的平均数量'。可见用户的操作频度是区分真实用户与机器人用户的关键指标。

# %%
feat_imp = pd.Series(xgb6.booster().get_fscore()).sort_values(ascending=False)
feat_imp.plot(kind='bar', title='Feature Importances')
plt.ylabel('Feature Importance Score')

# %% [markdown]
# ## 思考

# %% [markdown]
# 这个项目中，用户训练数据的样本数及特征数都很有限，有限的训练数据没法做好模型训练，但是平台提供了大量的竞拍行为数据，所以次项目的核心为特征工程，即是如何充分的对竞拍行为数据进行特征统计，为训练数据提供有效的特征，提高预测的准确性。
#
# 另外本项目中大量的数据都以字符串为格式，所以需要我们做好前期的特征变换工作，把字符串数据转化为可训练的数值数据。

# %% [markdown]
# ## 改进

# %% [markdown]
# 由于硬件性能所限，无法对竞拍行为数据进行大规模运算，通过之前的图形分析我们知道，真实用户的操作对比机器人用户会呈现出很强的周期性，如果用户的操作进行时间周期上的统计，是能够进一步提高模型的准确性的。
#
# 另外，我们把用户特征’地址‘剔除掉了，没有利用上，如果我们这些特征进行进一步的分析，可进一步提高模型表现。

# %% [markdown]
# # 引用

# %% [markdown]
# [1] LabelEncoding: http://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelEncoder.html
#
# [2] Xgboost: http://xgboost.readthedocs.io/en/latest/
#
# [3] LightGBM: https://github.com/Microsoft/LightGBM/wiki/Experiments
#
# [4] RandomForest: https://zh.wikipedia.org/wiki/%E9%9A%8F%E6%9C%BA%E6%A3%AE%E6%9E%97
#
# [5] Kaggle: https://www.kaggle.com/c/facebook-recruiting-iv-human-or-bot
#
# [6] Gradient Boosting: https://en.wikipedia.org/wiki/Gradient_boosting
#
# [7] 分布式加权直方图算法: http://blog.csdn.net/sb19931201/article/details/52557382
#
# [8] LightGBM介绍: http://www.jianshu.com/p/48e82dbb142b

# %%
y_pred=xgb6.predict_proba(X_predict)[:,1]
# X_predict_org = labelEncoder.inverse_transform(X_predict['bidder_id'])
pred_data=pd.DataFrame()
pred_data['bidder_id']=X_predict.index
pred_data['prediction']=y_pred
pred_data.to_csv('predictionV2.144-9.csv',index=False)
